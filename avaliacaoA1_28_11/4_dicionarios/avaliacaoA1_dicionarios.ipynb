# %% [markdown]
# <a href="https://colab.research.google.com/github/maycondesousapalacio-png/Tecnicas_e_desenvolvimento_de_Algoritmos/blob/main/avaliacaoA1_28_11/4_dicionarios/avaliacaoA1_dicionarios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''Desenvolver um sistema simples de cadastro de produtos com nome e preço, armazenando em dicionário.'''

produtos = {} #criando um dicionário vazio

while True:
    try:
        produto=input('Informe o nome do produto: ')     #entrada de dados
        valor=float(input("Informe o preço do produto: "))

        if produto=='':    #verifica se foi digitado um produto
            print('O nome do produto não pode ser vazio.')
            continue

        produtos[produto]=valor     #armazena os dados no dicionário

        for item,preco in produtos.items():    #exibe os itens armazenados com seus respectivos preços
            print('Nome do produto: ',item,' --- Preço: ',preco)

    except ValueError:   #tratamento de erro caso o valor do preço seja inválido
        print('Preço inválido, digite apenas números e ponto para valores decimais')

    else:   #verifica se o usuário deseja adicionar mais um produto
        res=input('Deseja adicionar mais algum produto? (s/n): ').lower()
        if res=='n' or res == 'nao' or res=='não':
            break

print('Programa finalizado.')
# Out:
# Informe o nome do produto: goiaba
# Informe o preço do produto: dois e cinquenta
# Preço inválido, digite apenas números e ponto para valores decimais
# Informe o nome do produto:
# Informe o preço do produto: 10
# O nome do produto não pode ser vazio.
# Informe o nome do produto: goiaba
# Informe o preço do produto: 2,35
# Preço inválido, digite apenas números e ponto para valores decimais
# Informe o nome do produto: maçã
# Informe o preço do produto: 2.35
# Nome do produto:  maçã  --- Preço:  2.35
# Deseja adicionar mais algum produto? (s/n): s
# Informe o nome do produto: caixa de ovos
# Informe o preço do produto: 22.00
# Nome do produto:  maçã  --- Preço:  2.35
# Nome do produto:  caixa de ovos  --- Preço:  22.0
# Deseja adicionar mais algum produto? (s/n): s
# Informe o nome do produto: shampoo
# Informe o preço do produto: 16.99
# Nome do produto:  maçã  --- Preço:  2.35
# Nome do produto:  caixa de ovos  --- Preço:  22.0
# Nome do produto:  shampoo  --- Preço:  16.99
# Deseja adicionar mais algum produto? (s/n): s
# Informe o nome do produto: óleo de soja
# Informe o preço do produto: 6.99
# Nome do produto:  maçã  --- Preço:  2.35
# Nome do produto:  caixa de ovos  --- Preço:  22.0
# Nome do produto:  shampoo  --- Preço:  16.99
# Nome do produto:  óleo de soja  --- Preço:  6.99
# Deseja adicionar mais algum produto? (s/n): n
# Programa finalizado.
